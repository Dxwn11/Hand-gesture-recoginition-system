# %% [markdown]
# Import Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %% [markdown]
# Define Dataset Path

# %%
train_path = r"C:\Project\part2\archive\asl_alphabet_train\asl_alphabet_train"

# %% [markdown]
# Image Preprocessing

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    train_path,
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    train_path,
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 51840 images belonging to 27 classes.
# Found 12960 images belonging to 27 classes.

# %% [markdown]
# Build CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape=(64,64,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))

# %% [markdown]
# Compile Model

# %%
model.add(Dense(train_data.num_classes,activation='softmax'))

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 1620/1620 [==============================] - 894s 550ms/step - loss: 1.3460 - accuracy: 0.5789 - val_loss: 0.9938 - val_accuracy: 0.6882
# Epoch 2/10
# 1620/1620 [==============================] - 99s 61ms/step - loss: 0.3402 - accuracy: 0.8820 - val_loss: 0.9507 - val_accuracy: 0.7508
# Epoch 3/10
# 1620/1620 [==============================] - 99s 61ms/step - loss: 0.1894 - accuracy: 0.9349 - val_loss: 0.9706 - val_accuracy: 0.7723
# Epoch 4/10
# 1620/1620 [==============================] - 101s 62ms/step - loss: 0.1261 - accuracy: 0.9562 - val_loss: 0.9460 - val_accuracy: 0.7866
# Epoch 5/10
# 1620/1620 [==============================] - 99s 61ms/step - loss: 0.1049 - accuracy: 0.9646 - val_loss: 0.9704 - val_accuracy: 0.7825
# Epoch 6/10
# 1620/1620 [==============================] - 99s 61ms/step - loss: 0.0803 - accuracy: 0.9732 - val_loss: 0.9404 - val_accuracy: 0.8107
# Epoch 7/10
# 1620/1620 [==============================] - 99s 61ms/step - loss: 0.0730 - accuracy: 0.9752 - val_loss: 1.0001 - val_accuracy: 0.7956
# Epoch 8/10
# 1620/1620 [==============================] - 100s 62ms/step - loss: 0.0605 - accuracy: 0.9799 - val_loss: 1.3137 - val_accuracy: 0.7943
# Epoch 9/10
# 1620/1620 [==============================] - 100s 62ms/step - loss: 0.0519 - accuracy: 0.9823 - val_loss: 1.1388 - val_accuracy: 0.7969
# Epoch 10/10
# 1620/1620 [==============================] - 110s 68ms/step - loss: 0.0518 - accuracy: 0.9844 - val_loss: 1.2755 - val_accuracy: 0.8027

# %% [markdown]
# Save Model

# %%
model.save("asl_model.h5")
